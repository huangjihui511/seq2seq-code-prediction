# %%
import javalang

# %%
s = """
    private ClassName(String packageName, ClassName enclosingClassName, String simpleName) {
this(packageName, enclosingClassName, simpleName, Collections.emptyList());
}
    """

# %%
s
# Out:
# '\n    private ClassName(String packageName, ClassName enclosingClassName, String simpleName) {\nthis(packageName, enclosingClassName, simpleName, Collections.emptyList());\n}\n    '

# %%
tokens = javalang.tokenizer.tokenize(s)
final_token_list = []

for token in tokens:
    final_token_list.append(token.value)
print (final_token_list)
# Out:
# ['private', 'ClassName', '(', 'String', 'packageName', ',', 'ClassName', 'enclosingClassName', ',', 'String', 'simpleName', ')', '{', 'this', '(', 'packageName', ',', 'enclosingClassName', ',', 'simpleName', ',', 'Collections', '.', 'emptyList', '(', ')', ')', ';', '}']

# %%
parser = javalang.parser.Parser(list(tokens))
parser.parse_expression()
# Out:
# ---------------------------------------------------------------------------
# JavaSyntaxError                           Traceback (most recent call last)
# <ipython-input-8-8d414718e10b> in <module>
#       1 parser = javalang.parser.Parser(list(tokens))
# ----> 2 parser.parse_expression()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parser.py in parse_expression(self)
#    1750     @parse_debug
#    1751     def parse_expression(self):
# -> 1752         expressionl = self.parse_expressionl()
#    1753         assignment_type = None
#    1754         assignment_expression = None
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parser.py in parse_expressionl(self)
#    1765     @parse_debug
#    1766     def parse_expressionl(self):
# -> 1767         expression_2 = self.parse_expression_2()
#    1768         true_expression = None
#    1769         false_expression = None
#
# ...

# %%
tokens = list(javalang.tokenizer.tokenize('Double a = 1;'))
parser = javalang.parser.Parser(tokens)
parser.parse_expression()
# Out:
# MemberReference(member=Double, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[])

# %%
tokens = javalang.tokenizer.tokenize('System.out.println("Hello " + "world");')
parser = javalang.parser.Parser(tokens)
parser.parse_type_declaration()
# Out:
# ---------------------------------------------------------------------------
# JavaSyntaxError                           Traceback (most recent call last)
# <ipython-input-30-54b30114393a> in <module>
#       1 tokens = javalang.tokenizer.tokenize('System.out.println("Hello " + "world");')
#       2 parser = javalang.parser.Parser(tokens)
# ----> 3 parser.parse_type_declaration()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parser.py in parse_type_declaration(self)
#     345             return None
#     346         else:
# --> 347             return self.parse_class_or_interface_declaration()
#     348
#     349     @parse_debug
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parser.py in parse_class_or_interface_declaration(self)
#     362             type_declaration = self.parse_annotation_type_declaration()
#     363         else:
# ...

# %%
tokens = javalang.tokenizer.tokenize('System.out.println("Hello " + "world");')
parser = javalang.parser.Parser(tokens)
parser.parse_expression()
# Out:
# MethodInvocation(arguments=[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Hello "), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="world"), operator=+)], member=println, postfix_operators=[], prefix_operators=[], qualifier=System.out, selectors=[], type_arguments=None)

# %%
data = open("HelloWorld.java").read()

# %%
print(data)
# Out:
# public class CallingMethodsInSameClass
# {
# 	public static void main(String[] args) {
# 		printOne();
# 		printOne();
# 		printTwo();
# 	}
#
# 	public static void printOne() {
# 		System.out.println("Hello World");
# 	}
#
# 	public static void printTwo() {
# 		printOne();
# 		printOne();
# 	}
# }

# %%
tokens = javalang.tokenizer.tokenize(data)
l = list(tokens)

# %%
str(type(l[0])).split(".")[-1].split("'")[0]
# Out:
# 'Modifier'

# %%
l[0],l[1],l[3],l[4],l[5],l[6],l[7]
# Out:
# (Modifier "public" line 1, position 1,
#  Keyword "class" line 1, position 8,
#  Separator "{" line 2, position 1,
#  Modifier "public" line 3, position 2,
#  Modifier "static" line 3, position 9,
#  Keyword "void" line 3, position 16,
#  Identifier "main" line 3, position 21)

# %%
class Mytree:
    father = None
    nodes = []
    def __init__(self, father, tokens):
        self.father = father
        flag_begin = []
        for index, token in enumerate(tokens):
            if token.value == "(" or token.value == "{":
                flag_begin.append(index)
            if token.value == ")" or token.value == "}":
                self.nodes.append(Mytree(self, tokens[flag_begin[-1]: index]))
            if len(flag_begin) == 0:
                self.nodes.append(token)
    
    def display(self, offset):
        for item in self.nodes:
            if type(item) != Mytree:
                print(item.value, end="")
            else:
                item.display(offset + 1)
                print("")

# %%
mytree = Mytree(None, l)
mytree.display(0)
# Out:
# a.util.ArrayList;importjava.util.Collections;importjava.util.List;importjava.util.Map;importjava.util.Objects;importjavax.lang.model.element.Element;importjavax.lang.model.element.PackageElement;importjavax.lang.model.element.TypeElement;importjavax.lang.model.util.SimpleElementVisitor8;importstaticcom.squareup.javapoet.Util.checkArgument;importstaticcom.squareup.javapoet.Util.checkNotNull;publicfinalclassClassNameextendsTypeNameimplementsComparable<ClassName>packagecom.squareup.javapoet;importjava.io.IOException;importjava.util.ArrayList;importjava.util.Collections;importjava.util.List;importjava.util.Map;importjava.util.Objects;importjavax.lang.model.element.Element;importjavax.lang.model.element.PackageElement;importjavax.lang.model.element.TypeElement;importjavax.lang.model.util.SimpleElementVisitor8;importstaticcom.squareup.javapoet.Util.checkArgument;importstaticcom.squareup.javapoet.Util.checkNotNull;publicfinalclassClassNameextendsTypeNameimplementsComparable<ClassName>packag
# ...

# %%
data = """
    from .ast import Node

# ------------------------------------------------------------------------------

class CompilationUnit(Node):
    attrs = ("package", "imports", "types")
    """

# %%
tree = javalang.parse.parse(data)
for path,node in tree:  
        print (path,node)
# Out:
# ---------------------------------------------------------------------------
# LexerError                                Traceback (most recent call last)
# <ipython-input-5-e96244dbfb62> in <module>
# ----> 1 tree = javalang.parse.parse(data)
#       2 for path,node in tree:
#       3         print (path,node)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parse.py in parse(s)
#      50 def parse(s):
#      51     tokens = tokenize(s)
# ---> 52     parser = Parser(tokens)
#      53     return parser.parse()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/javalang/parser.py in __init__(self, tokens)
#      93
#      94     def __init__(self, tokens):
# ---> 95         self.tokens = util.LookAheadListIterator(tokens)
#      96         self.tokens.set_default(EndOfInput(None))
#      97
#
# ...
